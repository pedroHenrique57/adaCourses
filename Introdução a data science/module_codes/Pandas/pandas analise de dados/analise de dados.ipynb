# %%
import pandas as pd

# %%
avaliacoes = pd.read_csv("../../../module_files/kaggle/Baldursgadedatabase/BG3_reviews_updated.csv")

# %%
avaliacoes
# Out:
#         recommendationid language  \
# 0              153560814  english
# 1              153560623  english
# 2              153560414  english
# 3              153560343  english
# 4              153559963  english
# ...                  ...      ...
# 309098          77139066  english
# 309099          77139054  english
# 309100          77139001  english
# 309101          77138476  english
# 309102          77136300  english
#
#                                                    review  timestamp_created  \
# 0               This game hits all the right marks. 10/10         1702542971
# 1          took me like 11 hours to understand the basics         1702542657
# 2       10/10 game play and story! It's my first turn ...         1702542275
# 3                                    gale is so baby girl         1702542158
# 4                         YES,\n\nWITHOUT A F****N DOUBT.         1702541518
# ...                                                   ...                ...
# 309098               can i have gay sex with the goblins?         1602008352
# 309099  F TO THE R TO THE E TO THE A TO THE K \n\nExci...         1602008342
# 309100                                             second         1602008270
# 309101  Within 5 min I already chose a dwarf female lo...         1602007516
# 309102  Asking an AAA price for an early-access Baldur...         1602004588
#
#         timestamp_updated  voted_up  votes_up  votes_funny  \
# 0              1702542971      True         0            0
# 1              1702542657      True         0            0
# 2              1702542275      True         0            0
# 3              1702542158      True         0            0
# 4              1702541518      True         0            0
# ...                   ...       ...       ...          ...
# 309098         1602008352      True       287          326
# 309099         1602008342      True        30            5
# 309100         1602008270      True        28            7
# 309101         1602007516      True       141          105
# 309102         1602004588     False      1683          799
#
#         weighted_vote_score  written_during_early_access  comment_count  \
# 0                  0.000000                        False              0
# 1                  0.000000                        False              0
# 2                  0.000000                        False              0
# 3                  0.000000                        False              0
# 4                  0.000000                        False              0
# ...                     ...                          ...            ...
# 309098             0.342165                         True              0
# 309099             0.047468                         True              0
# 309100             0.068515                         True              0
# 309101             0.402681                         True              8
# 309102             0.207539                         True            592
#
#         steam_purchase  received_for_free
# 0                 True              False
# 1                 True              False
# 2                 True              False
# 3                 True              False
# 4                 True              False
# ...                ...                ...
# 309098            True              False
# 309099            True              False
# 309100            True              False
# 309101            True              False
# 309102            True               True
#
# [309103 rows x 13 columns]

# %%
avaliacoes[avaliacoes['voted_up'] == False]
# Out:
#         recommendationid language  \
# 22             153557756  english
# 69             153554384  english
# 85             153552903  english
# 125            153549468  english
# 130            153549025  english
# ...                  ...      ...
# 309064          77141928  english
# 309075          77141008  english
# 309083          77140119  english
# 309084          77140087  english
# 309102          77136300  english
#
#                                                    review  timestamp_created  \
# 22      Yet another overhyped dogshit game.  How can a...         1702537509
# 69      Continuously crashes after 5-10 minutes of gam...         1702531546
# 85      It is a very fun game. however, my play throug...         1702529143
# 125     Firstly let me say this game will get a thumbs...         1702523972
# 130     Don't waste your time if you are planning on p...         1702523356
# ...                                                   ...                ...
# 309064  Was excited to play this game.\n\n3 years pass...         1602012252
# 309075  No gamepad support. Year of our lord 2020, and...         1602011007
# 309083  Game Breaking\n-Ghosting cameras through walls...         1602009827
# 309084  Though it's amusing watching Larian perform me...         1602009789
# 309102  Asking an AAA price for an early-access Baldur...         1602004588
#
#         timestamp_updated  voted_up  votes_up  votes_funny  \
# 22             1702537509     False         0            0
# 69             1702531546     False         0            0
# 85             1702530325     False         0            0
# 125            1702523972     False         1            1
# 130            1702523356     False         1            0
# ...                   ...       ...       ...          ...
# 309064         1689104526     False         1            0
# 309075         1602011007     False       108          173
# 309083         1602067276     False        34           11
# 309084         1691820889     False         3            0
# 309102         1602004588     False      1683          799
#
#         weighted_vote_score  written_during_early_access  comment_count  \
# 22                 0.478261                        False              0
# 69                 0.476190                        False              0
# 85                 0.000000                        False              0
# 125                0.441064                        False              0
# 130                0.500284                        False              0
# ...                     ...                          ...            ...
# 309064             0.476190                         True              0
# 309075             0.061605                         True            122
# 309083             0.315186                         True              0
# 309084             0.516230                         True              0
# 309102             0.207539                         True            592
#
#         steam_purchase  received_for_free
# 22                True              False
# 69                True              False
# 85                True              False
# 125               True              False
# 130               True              False
# ...                ...                ...
# 309064            True              False
# 309075            True              False
# 309083            True              False
# 309084            True              False
# 309102            True               True
#
# [10171 rows x 13 columns]

# %%
avaliacoes["voted_up"].value_counts()
# Out:
# voted_up
# True     298932
# False     10171
# Name: count, dtype: int64

# %%
print(avaliacoes.groupby(["written_during_early_access"])["voted_up"].value_counts())
# Out:
# written_during_early_access  voted_up
# False                        True        253976
#                              False         7079
# True                         True         44956
#                              False         3092
# Name: count, dtype: int64
